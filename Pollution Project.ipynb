# %%
import cv2
import numpy as np
import os

# %%
x1, y1 = -1, -1
drawing = False
image = np.full((500, 500, 3), (235, 206, 135), dtype=np.uint8)
c = 0


def mouse_tracking(event, x, y, flags, param):
    global x1, y1, drawing, image
    if event == cv2.EVENT_LBUTTONDOWN: 
        drawing = True
        x1, y1 = x, y
    elif event == cv2.EVENT_MOUSEMOVE and drawing: 
        temp_image = image.copy() 
        cv2.rectangle(temp_image, (x1, y1), (x, y), (255, 255, 255), -1)
        cv2.imshow("pollution", temp_image)
    elif event == cv2.EVENT_LBUTTONUP:
        drawing = False
        cv2.rectangle(image, (x1, y1), (x, y), (255, 255, 255), -1)
    elif event == cv2.EVENT_RBUTTONDOWN: 
        cv2.circle(image, (x, y), 20, (42, 42, 139), -1) 
    elif event == cv2.EVENT_MBUTTONDOWN:  
        cv2.circle(image, (x, y), 15, (0, 0, 0), -1) 
    elif event == cv2.EVENT_LBUTTONDBLCLK: 
        cv2.circle(image, (x, y), 15, (0, 255, 0), -1)  
    elif event == cv2.EVENT_MOUSEWHEEL:  
        cv2.circle(image, (x, y), 9, (245, 245, 245), -1)  


cv2.namedWindow("pollution")
cv2.setMouseCallback("pollution", mouse_tracking)

while True:
   
    cv2.imshow("pollution", image)

    
    if cv2.waitKey(1) & 255 == ord("s"):
        cv2.imwrite(r"C:\Users\JAYASREE\OneDrive\Desktop\ML\space1\{}.jpg".format(c), image)
        print(f"Frame {c} has been captured")
        c += 1 

    
    if cv2.waitKey(1) & 255 == ord("r"):
        image = np.full((500, 500, 3), (235, 206, 135), dtype=np.uint8) 

    
    if cv2.waitKey(1) & 255 == ord("q"):
        break


cv2.destroyAllWindows()
# Out:
# Frame 0 has been captured
# Frame 1 has been captured
# Frame 2 has been captured
# Frame 3 has been captured
# Frame 4 has been captured
# Frame 5 has been captured
# Frame 6 has been captured
# Frame 7 has been captured
# Frame 8 has been captured
# Frame 9 has been captured
# Frame 10 has been captured
# Frame 11 has been captured
# Frame 12 has been captured
# Frame 13 has been captured
# Frame 14 has been captured
# Frame 15 has been captured
# Frame 16 has been captured
# Frame 17 has been captured
# Frame 18 has been captured

# %%
import os

# %%
os.mkdir(r"C:\Users\JAYASREE\OneDrive\Desktop\ML\space1")

# %%
file_list = os.listdir(r"C:\Users\JAYASREE\OneDrive\Desktop\ML\space1")

sorted_files = sorted(file_list, key=lambda x: int(x.split('.')[0]))

for file_name in sorted_files:
    print(file_name)
# Out:
# 0.jpg
# 1.jpg
# 2.jpg
# 3.jpg
# 4.jpg
# 5.jpg
# 6.jpg
# 7.jpg
# 8.jpg
# 9.jpg
# 10.jpg
# 11.jpg
# 12.jpg
# 13.jpg
# 14.jpg
# 15.jpg
# 16.jpg
# 17.jpg
# 18.jpg

# %%
folder_path = r"C:\Users\JAYASREE\OneDrive\Desktop\ML\space1"
file_list = os.listdir(folder_path)
sorted_files = sorted(file_list, key=lambda x: int(x.split('.')[0]))
first_frame = True

# Frame counter
frame_count = 0

# Iterate through image frames
for file_name in sorted_files:
    file_path = os.path.join(folder_path, file_name)
    frame_count += 1
    
    img = cv2.imread(file_path)
    
    if img is not None:
        if first_frame:
            cv2.putText(img, "The Impact of Factory Pollution on Trees", (20, 40), 
                        cv2.FONT_HERSHEY_COMPLEX_SMALL, 0.9, (0, 100, 0), 1, cv2.LINE_AA)
            first_frame = False  

        if frame_count == 18:
            cv2.putText(img, "Pollution...!", (200, 300), 
                        cv2.FONT_HERSHEY_COMPLEX_SMALL, 2, (0, 0, 255), 1, cv2.LINE_AA)
        
        cv2.imshow("Frame", img)
        key = cv2.waitKey(1000)  # Display each frame for 1 second
        if key == 27:  # Exit on pressing 'Esc'
            print("Exiting...")
            break
    else:
        print(f"Failed to load image: {file_name}")

# Create a blank description page
description_page = np.zeros((500, 800, 3), dtype=np.uint8) + 255
cv2.putText(description_page, "Project Title: The Impact of Factory Pollution on Trees", (50, 50), 
            cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 0, 255), 1, cv2.LINE_AA)
cv2.putText(description_page, "Team Members:", (50, 100), 
            cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 0, 0), 1, cv2.LINE_AA)
cv2.putText(description_page, "1. Jayasree.M", (50, 140), 
            cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 0, 0), 1, cv2.LINE_AA)
cv2.putText(description_page, "2. Sahitya.S", (50, 180), 
            cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 0, 0), 1, cv2.LINE_AA)
cv2.putText(description_page, "3. Harshitha.M", (50, 220), 
            cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 0, 0), 1, cv2.LINE_AA)
cv2.putText(description_page, "4. Roopa.Ch", (50, 260), 
            cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 0, 0), 1, cv2.LINE_AA)
cv2.putText(description_page, "Thank You!", (50, 320), 
            cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 100, 0), 1, cv2.LINE_AA)

# Display the description page
cv2.imshow("Frame", description_page)
cv2.waitKey(3000)  # Show for 3 seconds

cv2.destroyAllWindows()

# %%
from PIL import Image

# Folder containing the images
folder_path = r"C:\Users\JAYASREE\OneDrive\Desktop\ML\space1"
file_list = os.listdir(folder_path)
sorted_files = sorted(file_list, key=lambda x: int(x.split('.')[0]))
first_frame = True

# Target size for all frames (ensure consistent dimensions)
frame_width, frame_height = 700, 500

# List to store frames for GIF
frames = []
frame_count = 0

# Iterate through image frames
for file_name in sorted_files:
    file_path = os.path.join(folder_path, file_name)
    frame_count += 1

    img = cv2.imread(file_path)
    
    if img is not None:
        # Resize image to target dimensions
        img = cv2.resize(img, (frame_width, frame_height))

        if first_frame:
            cv2.putText(img, "The Impact of Factory Pollution on Trees", (20, 40), 
                        cv2.FONT_HERSHEY_COMPLEX_SMALL, 0.9, (0, 100, 0), 1, cv2.LINE_AA)
            first_frame = False  

        if frame_count == 18:
            cv2.putText(img, "Pollution...!", (200, 300), 
                        cv2.FONT_HERSHEY_COMPLEX_SMALL, 2, (0, 0, 255), 1, cv2.LINE_AA)
        
        # Convert OpenCV frame (BGR) to RGB for Pillow
        frame_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        frames.append(Image.fromarray(frame_rgb))
    else:
        print(f"Failed to load image: {file_name}")

# Create a blank description page with the same size
description_page = np.zeros((frame_height, frame_width, 3), dtype=np.uint8) + 255
cv2.putText(description_page, "Project Title: The Impact of Factory Pollution on Trees", (50, 50), 
            cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 0, 255), 1, cv2.LINE_AA)
cv2.putText(description_page, "Team Members:", (50, 100), 
            cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 0, 0), 1, cv2.LINE_AA)
cv2.putText(description_page, "1. Sahitya.S", (50, 140), 
            cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 0, 0), 1, cv2.LINE_AA)
cv2.putText(description_page, "2. Harshitha.M", (50, 180), 
            cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 0, 0), 1, cv2.LINE_AA)
cv2.putText(description_page, "3. Jayasree.M", (50, 220), 
            cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 0, 0), 1, cv2.LINE_AA)
cv2.putText(description_page, "4. Roopa.Ch", (50, 260), 
            cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 0, 0), 1, cv2.LINE_AA)
cv2.putText(description_page, "Thank You!", (50, 320), 
            cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 100, 0), 1, cv2.LINE_AA)

# Convert description page to Pillow format and append to frames
description_rgb = cv2.cvtColor(description_page, cv2.COLOR_BGR2RGB)
frames.append(Image.fromarray(description_rgb))

# Save frames as a GIF
output_gif_path = r"C:\Users\JAYASREE\OneDrive\Desktop\ML\pollution.gif"
frames[0].save(output_gif_path, save_all=True, append_images=frames[1:], duration=1000, loop=0)

print(f"GIF saved at {output_gif_path}")
cv2.destroyAllWindows()
# Out:
# GIF saved at C:\Users\JAYASREE\OneDrive\Desktop\ML\pollution.gif
